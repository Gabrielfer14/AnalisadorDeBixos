# %% [markdown]
#  boxer	beagle	Siamese	Bengal

# %% [markdown]
# #IMPORTS#

# %%
from google.colab import files, drive
import os, io, time
from skimage.io import imread
from skimage.transform import resize
from skimage.feature import hog
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.applications.vgg19 import VGG19
import numpy as np

# %% [markdown]
# #Criando Diretorios

# %%
# Criando o diretório inicial: /content/
os.chdir('/content/')
try:
  os.mkdir('Imagens', )
except:
  print('A pasta já existe.')
os.chdir('./Imagens')
os.listdir()
uploaded_images = files.upload()
# Out:
#      <input type="file" id="files-3e6bb22b-29db-471b-adef-cc3a179fa417" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e6bb22b-29db-471b-adef-cc3a179fa417">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #HOG 128x128 16PIXEIS POR CELULA

# %%
hog_features = []
for filename in uploaded_images.keys():
  image = imread(filename)
  image_resized = resize(image, (128, 128))
  fd, hog_image = hog(image_resized, orientations = 9, pixels_per_cell = (16, 16), cells_per_block = (2, 2), visualize = True, channel_axis=-1)
  hog_features.append(fd)

# Substituindo as raças de cachorros e gatos por 'dog1', 'cat1', 'dog2' e 'cat2'
classe = ['dog1' if 'boxer' in file else 'dog2' if 'beagle' in file else 'cat1' if 'Siamese' in file else 'cat2' if 'Bengal' in file
           else file for file in uploaded_images.keys()]

import pandas as pd
## Adicionar as colunas com os valores do hog + classe
data = {"hog_features": hog_features, "classe": classe}
df = pd.DataFrame(data)

# Transformando cada valor do hog_feature em um atributo (coluna)
df2 = pd.DataFrame(df['hog_features'].tolist())
df2.columns = df2.columns.map(lambda x: f'hog_feature_{x+1}')
df = pd.concat([df.drop('hog_features', axis=1), df2], axis=1)

# Mover a coluna 'classe' para o final
df['classe'] = df.pop('classe')

# Salvando o CSV em uma pasta organizada
output_dir = '/content/resultados_hog_cnn'
os.makedirs(output_dir, exist_ok=True)
df.to_csv(os.path.join(output_dir, 'HOG_128_16x16.csv'), index=False)

# %% [markdown]
# #HOG 128x128 20PIXEIS POR CELULA

# %%
hog_features = []
for filename in uploaded_images.keys():
  image = imread(filename)
  image_resized = resize(image, (128, 128))
  fd, hog_image = hog(image_resized, orientations = 9, pixels_per_cell = (20, 20), cells_per_block = (2, 2), visualize = True, channel_axis=-1)
  hog_features.append(fd)

# Substituindo as raças de cachorros e gatos por 'dog1', 'cat1', 'dog2' e 'cat2'
classe = ['dog1' if 'boxer' in file else 'dog2' if 'beagle' in file else 'cat1' if 'Siamese' in file else 'cat2' if 'Bengal' in file
           else file for file in uploaded_images.keys()]

import pandas as pd
## Adicionar as colunas com os valores do hog + classe
data = {"hog_features": hog_features, "classe": classe}
df = pd.DataFrame(data)

# Transformando cada valor do hog_feature em um atributo (coluna)
df2 = pd.DataFrame(df['hog_features'].tolist())
df2.columns = df2.columns.map(lambda x: f'hog_feature_{x+1}')
df = pd.concat([df.drop('hog_features', axis=1), df2], axis=1)

# Mover a coluna 'classe' para o final
df['classe'] = df.pop('classe')

# Salvando o CSV em uma pasta organizada
output_dir = '/content/resultados_hog_cnn'
os.makedirs(output_dir, exist_ok=True)
df.to_csv(os.path.join(output_dir, 'HOG_128_20x20.csv'), index=False)

# %% [markdown]
# #HOG 256x256 16PIXEIS POR CELULA

# %%
hog_features = []
for filename in uploaded_images.keys():
  image = imread(filename)
  image_resized = resize(image, (256, 256))
  fd, hog_image = hog(image_resized, orientations = 9, pixels_per_cell = (16, 16), cells_per_block = (2, 2), visualize = True, channel_axis=-1)
  hog_features.append(fd)

# Substituindo as raças de cachorros e gatos por 'dog1', 'cat1', 'dog2' e 'cat2'
classe = ['dog1' if 'boxer' in file else 'dog2' if 'beagle' in file else 'cat1' if 'Siamese' in file else 'cat2' if 'Bengal' in file
           else file for file in uploaded_images.keys()]

import pandas as pd
## Adicionar as colunas com os valores do hog + classe
data = {"hog_features": hog_features, "classe": classe}
df = pd.DataFrame(data)

# Transformando cada valor do hog_feature em um atributo (coluna)
df2 = pd.DataFrame(df['hog_features'].tolist())
df2.columns = df2.columns.map(lambda x: f'hog_feature_{x+1}')
df = pd.concat([df.drop('hog_features', axis=1), df2], axis=1)

# Mover a coluna 'classe' para o final
df['classe'] = df.pop('classe')

# Sai da Pasta imagens para salvar os csv
os.chdir('/content/')

# Salvando o CSV em uma pasta organizada
output_dir = '/content/resultados_hog_cnn'
os.makedirs(output_dir, exist_ok=True)
df.to_csv(os.path.join(output_dir, 'HOG_256_16x16.csv'), index=False)

# %% [markdown]
# #HOG 256x256 20PIXEIS POR CELULA

# %%
os.chdir('./Imagens')

hog_features = []
for filename in uploaded_images.keys():
  image = imread(filename)
  image_resized = resize(image, (256, 256))
  fd, hog_image = hog(image_resized, orientations = 9, pixels_per_cell = (20, 20), cells_per_block = (2, 2), visualize = True, channel_axis=-1)
  hog_features.append(fd)

# Substituindo as raças de cachorros e gatos por 'dog1', 'cat1', 'dog2' e 'cat2'
classe = ['dog1' if 'boxer' in file else 'dog2' if 'beagle' in file else 'cat1' if 'Siamese' in file else 'cat2' if 'Bengal' in file
           else file for file in uploaded_images.keys()]

import pandas as pd
## Adicionar as colunas com os valores do hog + classe
data = {"hog_features": hog_features, "classe": classe}
df = pd.DataFrame(data)

# Transformando cada valor do hog_feature em um atributo (coluna)
df2 = pd.DataFrame(df['hog_features'].tolist())
df2.columns = df2.columns.map(lambda x: f'hog_feature_{x+1}')
df = pd.concat([df.drop('hog_features', axis=1), df2], axis=1)

# Mover a coluna 'classe' para o final
df['classe'] = df.pop('classe')

# Salvando o CSV em uma pasta organizada
output_dir = '/content/resultados_hog_cnn'
os.makedirs(output_dir, exist_ok=True)
df.to_csv(os.path.join(output_dir, 'HOG_256_20x20.csv'), index=False)

# %% [markdown]
# #CNN VGG16 128X128 POOLING MAX

# %%
## Carregar o modelo de CNN pre-treinado (VGG16)
model_16 = VGG16(weights='imagenet', include_top=False, pooling='max')

####### transformações ######
cnn_features = []
for filename in uploaded_images.keys():
  image = load_img(filename, target_size=(128, 128))
  print(filename)
  x = img_to_array(image)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)

  features = model_16.predict(x)
  features_flatten_vgg16 = features.flatten()
  cnn_features.append(features_flatten_vgg16)

# Substituindo as raças de cachorros e gatos por 'dog1', 'cat1', 'dog2' e 'cat2'
classe = ['dog1' if 'boxer' in file else 'dog2' if 'beagle' in file else 'cat1' if 'Siamese' in file else 'cat2' if 'Bengal' in file
           else file for file in uploaded_images.keys()]

import pandas as pd
## Adicionar as colunas com os valores do hog
data = {"classe": classe, "cnn_features": cnn_features}
df = pd.DataFrame(data)

# transformando cada valor do cnn_feature em um atributo (coluna)
df2 = pd.DataFrame(df['cnn_features'].tolist())
df2.columns = df2.columns.map(lambda x: f'cnn_feature_{x+1}')
df = pd.concat([df.drop('cnn_features', axis=1), df2], axis=1)

## Mover a coluna 'classe' para o final
df['classe'] = df.pop('classe')

# Salvando o CSV em uma pasta organizada
output_dir = '/content/resultados_hog_cnn'
os.makedirs(output_dir, exist_ok=True)
df.to_csv(os.path.join(output_dir, 'VGG16_128_MAX.csv'), index=False)
# Out:
# ...
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# beagle_1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# beagle_2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# beagle_3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# beagle_4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# beagle_5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# beagle_6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# beagle_7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# beagle_8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# beagle_9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# beagle_10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# beagle_12.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# beagle_13.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# beagle_14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# beagle_15.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# beagle_16.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# beagle_17.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# beagle_18.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# ...

# %% [markdown]
# #CNN VGG16 128X128 POOLING AVG

# %%
## Carregar o modelo de CNN pre-treinado (VGG16)
model_16 = VGG16(weights='imagenet', include_top=False, pooling='avg')

####### transformações ######
cnn_features = []
for filename in uploaded_images.keys():
  image = load_img(filename, target_size=(128, 128))
  print(filename)
  x = img_to_array(image)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)

  features = model_16.predict(x)
  features_flatten_vgg16 = features.flatten()
  cnn_features.append(features_flatten_vgg16)

# Substituindo as raças de cachorros e gatos por 'dog1', 'cat1', 'dog2' e 'cat2'
classe = ['dog1' if 'boxer' in file else 'dog2' if 'beagle' in file else 'cat1' if 'Siamese' in file else 'cat2' if 'Bengal' in file
           else file for file in uploaded_images.keys()]

import pandas as pd
## Adicionar as colunas com os valores do hog
data = {"classe": classe, "cnn_features": cnn_features}
df = pd.DataFrame(data)

# transformando cada valor do cnn_feature em um atributo (coluna)
df2 = pd.DataFrame(df['cnn_features'].tolist())
df2.columns = df2.columns.map(lambda x: f'cnn_feature_{x+1}')
df = pd.concat([df.drop('cnn_features', axis=1), df2], axis=1)

## Mover a coluna 'classe' para o final
df['classe'] = df.pop('classe')

# Salvando o CSV em uma pasta organizada
output_dir = '/content/resultados_hog_cnn'
os.makedirs(output_dir, exist_ok=True)
df.to_csv(os.path.join(output_dir, 'VGG16_128_AVG.csv'), index=False)
# Out:
# beagle_1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# beagle_2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# beagle_3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# beagle_4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# beagle_5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# beagle_6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# beagle_7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# beagle_8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# beagle_9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# beagle_10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# beagle_12.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# beagle_13.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# beagle_14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# beagle_15.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# beagle_16.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# beagle_17.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# beagle_18.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# beagle_19.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# ...

# %% [markdown]
# #CNN VGG16 256X256 POOLING MAX

# %%
## Carregar o modelo de CNN pre-treinado (VGG16)
model_16 = VGG16(weights='imagenet', include_top=False, pooling='max')

####### transformações ######
cnn_features = []
for filename in uploaded_images.keys():
  image = load_img(filename, target_size=(256, 256))
  print(filename)
  x = img_to_array(image)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)

  features = model_16.predict(x)
  features_flatten_vgg16 = features.flatten()
  cnn_features.append(features_flatten_vgg16)

# Substituindo as raças de cachorros e gatos por 'dog1', 'cat1', 'dog2' e 'cat2'
classe = ['dog1' if 'boxer' in file else 'dog2' if 'beagle' in file else 'cat1' if 'Siamese' in file else 'cat2' if 'Bengal' in file
           else file for file in uploaded_images.keys()]

import pandas as pd
## Adicionar as colunas com os valores do hog
data = {"classe": classe, "cnn_features": cnn_features}
df = pd.DataFrame(data)

# transformando cada valor do cnn_feature em um atributo (coluna)
df2 = pd.DataFrame(df['cnn_features'].tolist())
df2.columns = df2.columns.map(lambda x: f'cnn_feature_{x+1}')
df = pd.concat([df.drop('cnn_features', axis=1), df2], axis=1)

## Mover a coluna 'classe' para o final
df['classe'] = df.pop('classe')

# Salvando o CSV em uma pasta organizada
output_dir = '/content/resultados_hog_cnn'
os.makedirs(output_dir, exist_ok=True)
df.to_csv(os.path.join(output_dir, 'VGG16_256_MAX.csv'), index=False)

# %% [markdown]
# #CNN VGG16 256X256 POOLING AVG

# %%
## Carregar o modelo de CNN pre-treinado (VGG16)
model_16 = VGG16(weights='imagenet', include_top=False, pooling='avg')

####### transformações ######
cnn_features = []
for filename in uploaded_images.keys():
  image = load_img(filename, target_size=(256, 256))
  print(filename)
  x = img_to_array(image)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)

  features = model_16.predict(x)
  features_flatten_vgg16 = features.flatten()
  cnn_features.append(features_flatten_vgg16)

# Substituindo as raças de cachorros e gatos por 'dog1', 'cat1', 'dog2' e 'cat2'
classe = ['dog1' if 'boxer' in file else 'dog2' if 'beagle' in file else 'cat1' if 'Siamese' in file else 'cat2' if 'Bengal' in file
           else file for file in uploaded_images.keys()]

import pandas as pd
## Adicionar as colunas com os valores do hog
data = {"classe": classe, "cnn_features": cnn_features}
df = pd.DataFrame(data)

# transformando cada valor do cnn_feature em um atributo (coluna)
df2 = pd.DataFrame(df['cnn_features'].tolist())
df2.columns = df2.columns.map(lambda x: f'cnn_feature_{x+1}')
df = pd.concat([df.drop('cnn_features', axis=1), df2], axis=1)

## Mover a coluna 'classe' para o final
df['classe'] = df.pop('classe')

# Salvando o CSV em uma pasta organizada
output_dir = '/content/resultados_hog_cnn'
os.makedirs(output_dir, exist_ok=True)
df.to_csv(os.path.join(output_dir, 'VGG16_256_AVG.csv'), index=False)
# Out:
# beagle_1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# beagle_2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# beagle_3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# beagle_4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# beagle_5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# beagle_6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# beagle_7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# beagle_8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# beagle_9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# beagle_10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# beagle_12.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# beagle_13.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# beagle_14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# beagle_15.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# beagle_16.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# beagle_17.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# beagle_18.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# beagle_19.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# ...

# %% [markdown]
# #CNN VGG19 128x128 POOLING MAX

# %%
## Carregar o modelo de CNN pre-treinado (VGG16)
model_19 = VGG19(weights='imagenet', include_top=False, pooling='max')

####### transformações ######
cnn_features = []
for filename in uploaded_images.keys():
  image = load_img(filename, target_size=(128, 128))
  print(filename)
  x = img_to_array(image)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)

  features = model_19.predict(x)
  features_flatten_vgg19 = features.flatten()
  cnn_features.append(features_flatten_vgg19)

# Substituindo as raças de cachorros e gatos por 'dog1', 'cat1', 'dog2' e 'cat2'
classe = ['dog1' if 'boxer' in file else 'dog2' if 'beagle' in file else 'cat1' if 'Siamese' in file else 'cat2' if 'Bengal' in file
           else file for file in uploaded_images.keys()]

import pandas as pd
## Adicionar as colunas com os valores do hog
data = {"classe": classe, "cnn_features": cnn_features}
df = pd.DataFrame(data)

# transformando cada valor do cnn_feature em um atributo (coluna)
df2 = pd.DataFrame(df['cnn_features'].tolist())
df2.columns = df2.columns.map(lambda x: f'cnn_feature_{x+1}')
df = pd.concat([df.drop('cnn_features', axis=1), df2], axis=1)

## Mover a coluna 'classe' para o final
df['classe'] = df.pop('classe')

# Salvando o CSV em uma pasta organizada
output_dir = '/content/resultados_hog_cnn'
os.makedirs(output_dir, exist_ok=True)
df.to_csv(os.path.join(output_dir, 'VGG19_128_MAX.csv'), index=False)
# Out:
# ...
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# beagle_1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# beagle_2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# beagle_3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# beagle_4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# beagle_5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# beagle_6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# beagle_7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# beagle_8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# beagle_9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# beagle_10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# beagle_12.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# beagle_13.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# beagle_14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# beagle_15.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# beagle_16.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# beagle_17.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# beagle_18.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ...

# %% [markdown]
# #CNN VGG19 128x128 POOLING AVG

# %%
## Carregar o modelo de CNN pre-treinado (VGG16)
model_19 = VGG19(weights='imagenet', include_top=False, pooling='avg')

####### transformações ######
cnn_features = []
for filename in uploaded_images.keys():
  image = load_img(filename, target_size=(128, 128))
  print(filename)
  x = img_to_array(image)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)

  features = model_19.predict(x)
  features_flatten_vgg19 = features.flatten()
  cnn_features.append(features_flatten_vgg19)

# Substituindo as raças de cachorros e gatos por 'dog1', 'cat1', 'dog2' e 'cat2'
classe = ['dog1' if 'boxer' in file else 'dog2' if 'beagle' in file else 'cat1' if 'Siamese' in file else 'cat2' if 'Bengal' in file
           else file for file in uploaded_images.keys()]

import pandas as pd
## Adicionar as colunas com os valores do hog
data = {"classe": classe, "cnn_features": cnn_features}
df = pd.DataFrame(data)

# transformando cada valor do cnn_feature em um atributo (coluna)
df2 = pd.DataFrame(df['cnn_features'].tolist())
df2.columns = df2.columns.map(lambda x: f'cnn_feature_{x+1}')
df = pd.concat([df.drop('cnn_features', axis=1), df2], axis=1)

## Mover a coluna 'classe' para o final
df['classe'] = df.pop('classe')

# Salvando o CSV em uma pasta organizada
output_dir = '/content/resultados_hog_cnn'
os.makedirs(output_dir, exist_ok=True)
df.to_csv(os.path.join(output_dir, 'VGG19_128_AVG.csv'), index=False)
# Out:
# beagle_1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# beagle_2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# beagle_3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# beagle_4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# beagle_5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# beagle_6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# beagle_7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# beagle_8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# beagle_9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# beagle_10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# beagle_12.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# beagle_13.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# beagle_14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# beagle_15.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# beagle_16.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# beagle_17.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# beagle_18.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# beagle_19.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# ...

# %% [markdown]
# #CNN VGG19 256x256 POOLING MAX

# %%
## Carregar o modelo de CNN pre-treinado (VGG16)
model_19 = VGG19(weights='imagenet', include_top=False, pooling='max')

####### transformações ######
cnn_features = []
for filename in uploaded_images.keys():
  image = load_img(filename, target_size=(256, 256))
  print(filename)
  x = img_to_array(image)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)

  features = model_19.predict(x)
  features_flatten_vgg19 = features.flatten()
  cnn_features.append(features_flatten_vgg19)

# Substituindo as raças de cachorros e gatos por 'dog1', 'cat1', 'dog2' e 'cat2'
classe = ['dog1' if 'boxer' in file else 'dog2' if 'beagle' in file else 'cat1' if 'Siamese' in file else 'cat2' if 'Bengal' in file
           else file for file in uploaded_images.keys()]

import pandas as pd
## Adicionar as colunas com os valores do hog
data = {"classe": classe, "cnn_features": cnn_features}
df = pd.DataFrame(data)

# transformando cada valor do cnn_feature em um atributo (coluna)
df2 = pd.DataFrame(df['cnn_features'].tolist())
df2.columns = df2.columns.map(lambda x: f'cnn_feature_{x+1}')
df = pd.concat([df.drop('cnn_features', axis=1), df2], axis=1)

## Mover a coluna 'classe' para o final
df['classe'] = df.pop('classe')

# Salvando o CSV em uma pasta organizada
output_dir = '/content/resultados_hog_cnn'
os.makedirs(output_dir, exist_ok=True)
df.to_csv(os.path.join(output_dir, 'VGG19_256_MAX.csv'), index=False)
# Out:
# beagle_1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 846ms/step
# beagle_2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# beagle_3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# beagle_4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# beagle_5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# beagle_6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# beagle_7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# beagle_8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# beagle_9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# beagle_10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# beagle_12.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# beagle_13.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# beagle_14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# beagle_15.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# beagle_16.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# beagle_17.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# beagle_18.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# beagle_19.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ...

# %% [markdown]
# #CNN VGG19 256x256 POOLING AVG

# %%
## Carregar o modelo de CNN pre-treinado (VGG16)
model_19 = VGG19(weights='imagenet', include_top=False, pooling='avg')

####### transformações ######
cnn_features = []
for filename in uploaded_images.keys():
  image = load_img(filename, target_size=(256, 256))
  print(filename)
  x = img_to_array(image)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)

  features = model_19.predict(x)
  features_flatten_vgg19 = features.flatten()
  cnn_features.append(features_flatten_vgg19)

# Substituindo as raças de cachorros e gatos por 'dog1', 'cat1', 'dog2' e 'cat2'
classe = ['dog1' if 'boxer' in file else 'dog2' if 'beagle' in file else 'cat1' if 'Siamese' in file else 'cat2' if 'Bengal' in file
           else file for file in uploaded_images.keys()]

import pandas as pd
## Adicionar as colunas com os valores do hog
data = {"classe": classe, "cnn_features": cnn_features}
df = pd.DataFrame(data)

# transformando cada valor do cnn_feature em um atributo (coluna)
df2 = pd.DataFrame(df['cnn_features'].tolist())
df2.columns = df2.columns.map(lambda x: f'cnn_feature_{x+1}')
df = pd.concat([df.drop('cnn_features', axis=1), df2], axis=1)

## Mover a coluna 'classe' para o final
df['classe'] = df.pop('classe')

# Salvando o CSV em uma pasta organizada
output_dir = '/content/resultados_hog_cnn'
os.makedirs(output_dir, exist_ok=True)
df.to_csv(os.path.join(output_dir, 'VGG19_256_AVG.csv'), index=False)

# %% [markdown]
# #PCA 6 MELHORES BASES

# %%
from sklearn.decomposition import PCA
import pandas as pd

# Carrega a base
df = pd.read_csv('/content/VGG19_256_MAX.csv')

# Remove colunas que não são atributos numéricos (como "BASES TREINO/TESTE" se existir)
colunas_numericas = df.select_dtypes(include='number').columns
X = df[colunas_numericas]

# Separa o rótulo (classe)
y = df['classe'] if 'classe' in df.columns else None

# Aplica o PCA com 10 componentes
pca = PCA(n_components=10)
X_pca = pca.fit_transform(X)

# Cria novo DataFrame com os 10 componentes
df_pca = pd.DataFrame(X_pca, columns=[f'pca_{i+1}' for i in range(10)])
if y is not None:
    df_pca['classe'] = y

# Salva novo CSV
df_pca.to_csv('/content/VGG19_256_MAX_PCA.csv', index=False)
